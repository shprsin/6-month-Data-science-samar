# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Q1

# %%
# Maltplotlib is python Library used for data Analysis and Visualisation.
# It is used to represent data in various forms for analysis.
# Some plots are: Line plot, Scatter plot, Bar plot, Histogram, 3D Plot and others

# %% [markdown]
# Q2

# %%
np.random.seed(3) 
x = 3 + np.random.normal(0, 2, 50) 
y = 3 + np.random.normal(0, 2, len(x)) 
plt.xlabel('This my X')
plt.ylabel('This is my Y')
plt.title('This is my Title')
plt.scatter(x,y)

# %% [markdown]
# Q3

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([50, 20, 40, 20, 60, 70]) 
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([10, 20, 30, 40, 50, 60]) 
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,1)
plt.plot(x,y,'r')
plt.subplot(2,2,2)
plt.plot(x1,y1,'y')
plt.subplot(2,2,3)
plt.plot(x2,y2,'g')
plt.subplot(2,2,4)
plt.plot(x3,y3)

# %% [markdown]
# Q4

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"]) 
profit = np.array([3000, 8000, 1000, 10000])
plt.subplot(2,2,1)
plt.bar(company,profit)
plt.subplot(2,2,2)
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5

# %%
#Box plots provide a quick visual summary of the variability of values in a dataset. They show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the datase
box1 = np.random.normal(100, 10, 200) 
box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe9ecda1450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe9ecda1990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe9ecda10f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe9ecda1ed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe9ecda20b0>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe9ecd97130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe9ecd946a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe9ecd7fdc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe9ed8da950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe9ecdf6b00>],
#  'means': []}
