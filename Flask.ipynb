# %%
#1 
#Flask is python Library used for Building Web based applications. 
#Advantage:
#It is a lightweight framework that offers hassle-free development.
#Provide flexibility to the developer to experiment with their modules or architecture.
#It is suitable for small projects.
#Offers a built-in development server and fast debugger.
#Easily scalable for the applications.
#Support for secure cookies.

# %% [raw]
# from flask import Flask
# from flask import request
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h1>Hello, World!"

# %% [markdown]
# ![Screenshot (30).png](attachment:fd592c0f-5b94-461f-be57-c71d1773ca46.png)

# %%
#3
#In Flask, the process of defining the URLs that map to specific functions or methods in your application is known as routing. We use routing to access functions.

# %% [raw]
# #4
# from flask import Flask
# from flask import request
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     n="ABC Corporation"
#     l='India'
#     return "Company Name : {} <br>  Location : {} <br> Contact Details : 999-999-9999".format(n,l)
#
# @app.route("/welcome")
# def welcome():
#     return 'Welcome to ABC Corporation'

# %% [markdown]
# ![Screenshot (31).png](attachment:a3155efa-cc6a-4d35-b83a-32cd4b4f376d.png)
# ![Screenshot (32).png](attachment:fb108146-5210-4ef7-bd23-1e717397b5d0.png)

# %%
#5
#The url_for() function is very useful for dynamically building a URL for a specific function
